# %% [markdown]
# # EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import xgboost as xgb

import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.preprocessing import StandardScaler, LabelEncoder
from pmdarima import auto_arima
from scipy.stats import pearsonr
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv('01_02_Data_cleaned_Client1.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83235 entries, 0 to 83234
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventName           83235 non-null  object
#  1   StartDate           83235 non-null  object
#  2   EventType           83235 non-null  object
#  3   BookingReference    83235 non-null  object
#  4   AttendeeReference   83235 non-null  object
#  5   GroupSize           83235 non-null  int64
#  6   IsLeadAttendee      83235 non-null  bool
#  7   AttendeeGrossCost   83235 non-null  float64
#  8   EventId             83235 non-null  int64
#  9   BookingStatus       83235 non-null  object
#  10  AttendeeType        83235 non-null  object
#  11  TicketType          83235 non-null  object
#  12  StatusCreatedDate   83235 non-null  object
#  13  ClientId            83235 non-null  int64
#  14  StartYear           83235 non-null  int64
#  15  StartMonth          83235 non-null  int64
#  16  StatusCreatedYear   83235 non-null  int64
#  17  StatusCreatedMonth  83235 non-null  int64
#  18  StartWeek           83235 non-null  int64
#  19  StatusCreatedWeek   83235 non-null  int64
# dtypes: bool(1), float64(1), int64(9), object(9)
# memory usage: 12.1+ MB

# %%
data.head(10)
# Out:
#                                            EventName            StartDate  \
# 0  Neoliberalism. the Family. and Bourgeois Domes...  2021-10-12 15:00:00
# 1                                 Queer Homemaking I  2021-10-22 15:00:00
# 2  Neoliberalism. the Family. and Bourgeois Domes...  2021-10-12 15:00:00
# 3                                 Queer Homemaking I  2021-10-22 15:00:00
# 4  Neoliberalism. the Family. and Bourgeois Domes...  2021-10-12 15:00:00
# 5  Neoliberalism. the Family. and Bourgeois Domes...  2021-10-12 15:00:00
# 6                                Queer Homemaking II  2021-11-19 15:00:00
# 7  Neoliberalism. the Family. and Bourgeois Domes...  2022-01-21 15:00:00
# 8  Financial Technology - Challenges for the Law ...  2021-03-09 09:30:00
# 9  Financial Technology - Challenges for the Law ...  2021-03-09 09:30:00
#
#        EventType BookingReference AttendeeReference  GroupSize  \
# 0        Seminar          B953419          A1021430          1
# 1  Reading Group          B954541          A1022562          1
# 2        Seminar          B956238          A1024268          1
# 3  Reading Group          B959604          A1027663          1
# 4        Seminar          B959608          A1027667          1
# 5        Seminar          B967598          A1035704          1
# 6        Seminar          B972756          A1040883          1
# 7        Seminar          B972760          A1040887          1
# 8        Seminar          B977104          A1045245          1
# 9        Seminar          B977116          A1045257          1
#
#    IsLeadAttendee  AttendeeGrossCost  EventId BookingStatus AttendeeType  \
# 0            True                0.0    24077     Attending     Attendee
# 1            True                0.0    24071     Attending     Attendee
# 2            True                0.0    24077     Attending     Attendee
# 3            True                0.0    24071     Attending     Attendee
# 4            True                0.0    24077     Attending     Attendee
# 5            True                0.0    24077     Attending     Attendee
# 6            True                0.0    24075     Attending     Attendee
# 7            True                0.0    24078     Attending     Attendee
# 8            True                0.0    24371     Attending     Attendee
# 9            True                0.0    24371     Attending     Attendee
#
#   TicketType    StatusCreatedDate  ClientId  StartYear  StartMonth  \
# 0   Standard  2021-05-03 16:27:00       219       2021          10
# 1   Standard  2021-08-03 17:02:00       219       2021          10
# 2   Standard  2021-10-03 16:44:00       219       2021          10
# 3   Standard  2021-03-16 17:33:00       219       2021          10
# 4   Standard  2021-03-16 17:35:00       219       2021          10
# 5   Standard  2021-12-04 13:16:00       219       2021          10
# 6   Standard  2021-04-21 15:32:00       219       2021          11
# 7   Standard  2021-04-21 15:35:00       219       2022           1
# 8   Standard  2021-02-05 07:49:00       219       2021           3
# 9   Standard  2021-02-05 10:24:00       219       2021           3
#
#    StatusCreatedYear  StatusCreatedMonth  StartWeek  StatusCreatedWeek
# 0               2021                   5         41                 18
# 1               2021                   8         42                 31
# 2               2021                  10         41                 39
# 3               2021                   3         42                 11
# 4               2021                   3         41                 11
# 5               2021                  12         41                 48
# 6               2021                   4         46                 16
# 7               2021                   4          3                 16
# 8               2021                   2         10                  5
# 9               2021                   2         10                  5

# %%
data['StartDate'] = pd.to_datetime(data['StartDate'], infer_datetime_format=True)
data['StatusCreatedDate'] = pd.to_datetime(data['StatusCreatedDate'], infer_datetime_format=True)

# %%
# Creating the Season column
_condition_winter = (data.StartDate.dt.month>=1)&(data.StartDate.dt.month<=3)
_condtion_spring = (data.StartDate.dt.month>=4)&(data.StartDate.dt.month<=6)
_condition_summer = (data.StartDate.dt.month>=7)&(data.StartDate.dt.month<=9)
_condition_autumn = (data.StartDate.dt.month>=10)&(data.StartDate.dt.month<=12)
data['Season'] = np.where(_condition_winter,'Winter',np.where(_condtion_spring,'Spring',np.where(_condition_summer,'Summer',np.where(_condition_autumn,'Autumn',np.nan))))

# %%
# Creating Days to Event
data['Days to Event'] = (data['StartDate'] - data['StatusCreatedDate']).dt.days

# %%
data.head()
# Out:
#                                            EventName           StartDate  \
# 0  Neoliberalism. the Family. and Bourgeois Domes... 2021-10-12 15:00:00
# 1                                 Queer Homemaking I 2021-10-22 15:00:00
# 2  Neoliberalism. the Family. and Bourgeois Domes... 2021-10-12 15:00:00
# 3                                 Queer Homemaking I 2021-10-22 15:00:00
# 4  Neoliberalism. the Family. and Bourgeois Domes... 2021-10-12 15:00:00
#
#        EventType BookingReference AttendeeReference  GroupSize  \
# 0        Seminar          B953419          A1021430          1
# 1  Reading Group          B954541          A1022562          1
# 2        Seminar          B956238          A1024268          1
# 3  Reading Group          B959604          A1027663          1
# 4        Seminar          B959608          A1027667          1
#
#    IsLeadAttendee  AttendeeGrossCost  EventId BookingStatus  ...  \
# 0            True                0.0    24077     Attending  ...
# 1            True                0.0    24071     Attending  ...
# 2            True                0.0    24077     Attending  ...
# 3            True                0.0    24071     Attending  ...
# 4            True                0.0    24077     Attending  ...
#
#     StatusCreatedDate ClientId StartYear  StartMonth  StatusCreatedYear  \
# 0 2021-05-03 16:27:00      219      2021          10               2021
# 1 2021-08-03 17:02:00      219      2021          10               2021
# 2 2021-10-03 16:44:00      219      2021          10               2021
# 3 2021-03-16 17:33:00      219      2021          10               2021
# 4 2021-03-16 17:35:00      219      2021          10               2021
#
#    StatusCreatedMonth  StartWeek  StatusCreatedWeek  Season  Days to Event
# 0                   5         41                 18  Autumn            161
# 1                   8         42                 31  Autumn             79
# 2                  10         41                 39  Autumn              8
# 3                   3         42                 11  Autumn            219
# 4                   3         41                 11  Autumn            209
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83235 entries, 0 to 83234
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventName           83235 non-null  object
#  1   StartDate           83235 non-null  datetime64[ns]
#  2   EventType           83235 non-null  object
#  3   BookingReference    83235 non-null  object
#  4   AttendeeReference   83235 non-null  object
#  5   GroupSize           83235 non-null  int64
#  6   IsLeadAttendee      83235 non-null  bool
#  7   AttendeeGrossCost   83235 non-null  float64
#  8   EventId             83235 non-null  int64
#  9   BookingStatus       83235 non-null  object
#  10  AttendeeType        83235 non-null  object
#  11  TicketType          83235 non-null  object
#  12  StatusCreatedDate   83235 non-null  datetime64[ns]
#  13  ClientId            83235 non-null  int64
#  14  StartYear           83235 non-null  int64
#  15  StartMonth          83235 non-null  int64
#  16  StatusCreatedYear   83235 non-null  int64
#  17  StatusCreatedMonth  83235 non-null  int64
#  18  StartWeek           83235 non-null  int64
#  19  StatusCreatedWeek   83235 non-null  int64
#  20  Season              83235 non-null  object
#  21  Days to Event       83235 non-null  int64
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(10), object(8)
# memory usage: 13.4+ MB

# %%
# Using drop() to delete row based with '#NUM!'

data.drop(data[data['Days to Event'] < 0].index, inplace=True)

# %%
# Creating weeks to Event
data['Weeks to Event'] = data['Days to Event'].div(7).round(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61436 entries, 0 to 83209
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventName           61436 non-null  object
#  1   StartDate           61436 non-null  datetime64[ns]
#  2   EventType           61436 non-null  object
#  3   BookingReference    61436 non-null  object
#  4   AttendeeReference   61436 non-null  object
#  5   GroupSize           61436 non-null  int64
#  6   IsLeadAttendee      61436 non-null  bool
#  7   AttendeeGrossCost   61436 non-null  float64
#  8   EventId             61436 non-null  int64
#  9   BookingStatus       61436 non-null  object
#  10  AttendeeType        61436 non-null  object
#  11  TicketType          61436 non-null  object
#  12  StatusCreatedDate   61436 non-null  datetime64[ns]
#  13  ClientId            61436 non-null  int64
#  14  StartYear           61436 non-null  int64
#  15  StartMonth          61436 non-null  int64
#  16  StatusCreatedYear   61436 non-null  int64
#  17  StatusCreatedMonth  61436 non-null  int64
#  18  StartWeek           61436 non-null  int64
#  19  StatusCreatedWeek   61436 non-null  int64
#  20  Season              61436 non-null  object
#  21  Days to Event       61436 non-null  int64
#  22  Weeks to Event      61436 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(2), int64(10), object(8)
# memory usage: 10.8+ MB

# %%
data['Days to Event'].isnull().sum()
# Out:
# 0

# %%
# Dropping rows with "Cancelled" in event name column
data.drop(data[~data["EventName"].str.contains('CANCELLED')==False].index, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60694 entries, 0 to 83209
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventName           60694 non-null  object
#  1   StartDate           60694 non-null  datetime64[ns]
#  2   EventType           60694 non-null  object
#  3   BookingReference    60694 non-null  object
#  4   AttendeeReference   60694 non-null  object
#  5   GroupSize           60694 non-null  int64
#  6   IsLeadAttendee      60694 non-null  bool
#  7   AttendeeGrossCost   60694 non-null  float64
#  8   EventId             60694 non-null  int64
#  9   BookingStatus       60694 non-null  object
#  10  AttendeeType        60694 non-null  object
#  11  TicketType          60694 non-null  object
#  12  StatusCreatedDate   60694 non-null  datetime64[ns]
#  13  ClientId            60694 non-null  int64
#  14  StartYear           60694 non-null  int64
#  15  StartMonth          60694 non-null  int64
#  16  StatusCreatedYear   60694 non-null  int64
#  17  StatusCreatedMonth  60694 non-null  int64
#  18  StartWeek           60694 non-null  int64
#  19  StatusCreatedWeek   60694 non-null  int64
#  20  Season              60694 non-null  object
#  21  Days to Event       60694 non-null  int64
#  22  Weeks to Event      60694 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(2), int64(10), object(8)
# memory usage: 10.7+ MB

# %%
# Dropping rows with "Cancel;ed" in BookingStatus column
data.drop(data[data["BookingStatus"] == "Cancelled"].index, inplace= True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60623 entries, 0 to 83209
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventName           60623 non-null  object
#  1   StartDate           60623 non-null  datetime64[ns]
#  2   EventType           60623 non-null  object
#  3   BookingReference    60623 non-null  object
#  4   AttendeeReference   60623 non-null  object
#  5   GroupSize           60623 non-null  int64
#  6   IsLeadAttendee      60623 non-null  bool
#  7   AttendeeGrossCost   60623 non-null  float64
#  8   EventId             60623 non-null  int64
#  9   BookingStatus       60623 non-null  object
#  10  AttendeeType        60623 non-null  object
#  11  TicketType          60623 non-null  object
#  12  StatusCreatedDate   60623 non-null  datetime64[ns]
#  13  ClientId            60623 non-null  int64
#  14  StartYear           60623 non-null  int64
#  15  StartMonth          60623 non-null  int64
#  16  StatusCreatedYear   60623 non-null  int64
#  17  StatusCreatedMonth  60623 non-null  int64
#  18  StartWeek           60623 non-null  int64
#  19  StatusCreatedWeek   60623 non-null  int64
#  20  Season              60623 non-null  object
#  21  Days to Event       60623 non-null  int64
#  22  Weeks to Event      60623 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(2), int64(10), object(8)
# memory usage: 10.7+ MB

# %%
# Creating Days to Event
# data['Sell Out Time'] = (data['StartDate'] - data['StatusCreatedDate']).dt.days

# %% [markdown]
# ## Thoughts
#
# Questions?
# 1. If I am to host an event, when can I start panicking that I may not sell enough tickets?
# 2. When can I start panicking that I may eventually sell more tickets than planned ?
# 3. When can I tell my client to change their venue to a smaller or bigger place?
# 4. How long can I tell my client to leave their sales open for to get their maximum number of sales without doing anything? This is coupled with the seasons of when ticket sales starts maybe.
#
# 3 things Gerald wants to see.
# 1.	How long to sell out tickets irrespective of your event
# 2.	The approximate number of tickets it will sell.
# 3.	Give me a distribution of the number of tickets.
#
# 2 & 3 answered the same

# %% [markdown]
# # Question 1
#
# How long to sell out tickets irrespective of your event ?

# %%
data0 = data.groupby(['Season','StartWeek','StartYear','StartMonth','StartDate','EventType','Weeks to Event'], as_index=False).agg(
                                                                                            Min_Purchase_Day = pd.NamedAgg(column='StatusCreatedDate', aggfunc='min'),
                                                                                            Max_Purchase_Day = pd.NamedAgg(column='StatusCreatedDate', aggfunc='max'),  
                                                                                            Num_of_ticket = pd.NamedAgg(column='BookingReference', aggfunc='count')
)
data0['Purchase_Period'] = (data0['Max_Purchase_Day'] - data0['Min_Purchase_Day']).dt.days

# %%
# data1 = data.groupby(['Season','StartDate','EventId','Weeks to Event'], as_index=False).agg({'StatusCreatedDate': lambda SellOutDate: (SellOutDate.max() - SellOutDate.min()).days})
# data1.rename(columns={'StatusCreatedDate': 'Purchase Period (Days)'}, inplace=True)

data1 = data.groupby(['Season','StartWeek','StartYear','StartMonth','StartDate','EventType','Weeks to Event'], as_index=False).agg(
                                                                                            Min_Purchase_Day = pd.NamedAgg(column='StatusCreatedDate', aggfunc='min'),
                                                                                            Max_Purchase_Day = pd.NamedAgg(column='StatusCreatedDate', aggfunc='max'),  
                                                                                            Num_of_ticket = pd.NamedAgg(column='BookingReference', aggfunc='count')
                                                                                            )
# data1['Min Purchase Day'] = data1['StatusCreatedDate'].min

data1['Purchase_Period'] = (data1['Max_Purchase_Day'] - data1['Min_Purchase_Day']).dt.days
data1
# Out:
#       Season  StartWeek  StartYear  StartMonth           StartDate  \
# 0     Autumn         39       2022          10 2022-10-01 10:00:00
# 1     Autumn         39       2022          10 2022-10-01 18:00:00
# 2     Autumn         39       2022          10 2022-10-01 18:00:00
# 3     Autumn         39       2022          10 2022-10-01 18:00:00
# 4     Autumn         39       2022          10 2022-10-01 18:00:00
# ...      ...        ...        ...         ...                 ...
# 8544  Winter         52       2022           1 2022-01-02 18:00:00
# 8545  Winter         52       2022           1 2022-01-02 18:30:00
# 8546  Winter         52       2022           1 2022-01-02 18:30:00
# 8547  Winter         52       2022           1 2022-01-02 18:30:00
# 8548  Winter         52       2022           1 2022-01-02 18:30:00
#
#               EventType  Weeks to Event    Min_Purchase_Day  \
# 0     Research Training            41.0 2021-12-16 12:02:00
# 1               Seminar             4.0 2022-09-01 00:24:00
# 2               Seminar             9.0 2022-08-01 03:40:00
# 3               Seminar            13.0 2022-07-01 10:37:00
# 4               Seminar            17.0 2022-06-01 09:35:00
# ...                 ...             ...                 ...
# 8544            Seminar             1.0 2021-12-29 04:55:00
# 8545            Lecture             0.0 2021-12-30 17:45:00
# 8546            Lecture             1.0 2021-12-23 00:55:00
# 8547            Lecture             2.0 2021-12-16 21:12:00
# 8548            Lecture             3.0 2021-12-14 18:45:00
#
#         Max_Purchase_Day  Num_of_ticket  Purchase_Period
# 0    2021-12-16 12:02:00              1                0
# 1    2022-09-01 23:24:00             40                0
# 2    2022-08-01 22:10:00             14                0
# 3    2022-07-01 21:26:00             28                0
# 4    2022-06-01 18:29:00              5                0
# ...                  ...            ...              ...
# 8544 2021-12-29 04:55:00              1                0
# 8545 2022-01-02 13:19:00              8                2
# 8546 2021-12-28 19:04:00             27                5
# 8547 2021-12-19 22:53:00              3                3
# 8548 2021-12-15 11:25:00              2                0
#
# [8549 rows x 11 columns]

# %%
# Do cumum here
# data1['cum_purchase'] = data1['Purchase_Period'].cumsum(axis=0)

# %%
data2 = data.groupby(['Season','StartYear','StartMonth','StartWeek','StartDate','EventType','Weeks to Event'], as_index=False).agg({'BookingReference':'count'})
data2
# Out:
#       Season  StartYear  StartMonth  StartWeek           StartDate  \
# 0     Autumn       2021          10         40 2021-10-09 13:00:00
# 1     Autumn       2021          10         41 2021-10-11 11:00:00
# 2     Autumn       2021          10         41 2021-10-11 11:00:00
# 3     Autumn       2021          10         41 2021-10-11 11:00:00
# 4     Autumn       2021          10         41 2021-10-11 11:00:00
# ...      ...        ...         ...        ...                 ...
# 8544  Winter       2022           3         13 2022-03-31 18:00:00
# 8545  Winter       2022           3         13 2022-03-31 18:00:00
# 8546  Winter       2022           3         13 2022-03-31 18:00:00
# 8547  Winter       2022           3         13 2022-03-31 18:00:00
# 8548  Winter       2022           3         13 2022-03-31 18:00:00
#
#               EventType  Weeks to Event  BookingReference
# 0     Research Training            12.0                25
# 1     Research Training             0.0                 3
# 2     Research Training             1.0                 1
# 3     Research Training             2.0                 8
# 4     Research Training             4.0                16
# ...                 ...             ...               ...
# 8544            Seminar             9.0                 8
# 8545            Seminar            10.0                 7
# 8546            Seminar            11.0                 3
# 8547            Seminar            12.0                 5
# 8548            Seminar            13.0                 1
#
# [8549 rows x 8 columns]

# %%
# data2['cum_booking'] = data2['BookingReference'].cumsum(axis=0)

# %% [markdown]
# # XGBoost Model
# Use an XGBoost model to predict the Sell Out Period (Days) and number of bookings (BookingReference). Consider 30 percent of
# data for testing.

# %%
# Set the StartDate as index
data1 =data1.set_index('StartDate')

# %% [markdown]
# ### Encoding Categorical Varibles
# When training a machine learning model, all categorical variables must be convert into numeric form. Here, the `LabelEncoder` is used.

# %%
# Get all categorical variales
categorical_col = data1.columns[data1.dtypes == "object"].to_list()
categorical_col
# Out:
# ['Season', 'EventType']

# %%
LE = LabelEncoder()

for col in categorical_col:
    # Transoform to numeric form
    data1[col] = LE.fit_transform(data1[col])

# %%
data1.head(3)
# Out:
#                      Season  StartWeek  StartYear  StartMonth  EventType  \
# StartDate
# 2022-10-01 10:00:00       0         39       2022          10          7
# 2022-10-01 18:00:00       0         39       2022          10          8
# 2022-10-01 18:00:00       0         39       2022          10          8
#
#                      Weeks to Event    Min_Purchase_Day    Max_Purchase_Day  \
# StartDate
# 2022-10-01 10:00:00            41.0 2021-12-16 12:02:00 2021-12-16 12:02:00
# 2022-10-01 18:00:00             4.0 2022-09-01 00:24:00 2022-09-01 23:24:00
# 2022-10-01 18:00:00             9.0 2022-08-01 03:40:00 2022-08-01 22:10:00
#
#                      Num_of_ticket  Purchase_Period
# StartDate
# 2022-10-01 10:00:00              1                0
# 2022-10-01 18:00:00             40                0
# 2022-10-01 18:00:00             14                0

# %% [markdown]
# ### Feature Collection

# %%
def create_features(df):
    '''
    Create time series features based on time series index
    '''
    data1['StartHour'] = data1.index.hour
    data1['StartDayofweek'] = data1.index.dayofweek
    data1['StartQuarter'] = data1.index.quarter
    data1['StartDayofyear'] = data1.index.dayofyear
    return df

# %%
data1 = create_features(data1)

# %%
data1
# Out:
#                      Season  StartWeek  StartYear  StartMonth  EventType  \
# StartDate
# 2022-10-01 10:00:00       0         39       2022          10          7
# 2022-10-01 18:00:00       0         39       2022          10          8
# 2022-10-01 18:00:00       0         39       2022          10          8
# 2022-10-01 18:00:00       0         39       2022          10          8
# 2022-10-01 18:00:00       0         39       2022          10          8
# ...                     ...        ...        ...         ...        ...
# 2022-01-02 18:00:00       3         52       2022           1          8
# 2022-01-02 18:30:00       3         52       2022           1          3
# 2022-01-02 18:30:00       3         52       2022           1          3
# 2022-01-02 18:30:00       3         52       2022           1          3
# 2022-01-02 18:30:00       3         52       2022           1          3
#
#                      Weeks to Event    Min_Purchase_Day    Max_Purchase_Day  \
# StartDate
# 2022-10-01 10:00:00            41.0 2021-12-16 12:02:00 2021-12-16 12:02:00
# 2022-10-01 18:00:00             4.0 2022-09-01 00:24:00 2022-09-01 23:24:00
# 2022-10-01 18:00:00             9.0 2022-08-01 03:40:00 2022-08-01 22:10:00
# 2022-10-01 18:00:00            13.0 2022-07-01 10:37:00 2022-07-01 21:26:00
# 2022-10-01 18:00:00            17.0 2022-06-01 09:35:00 2022-06-01 18:29:00
# ...                             ...                 ...                 ...
# 2022-01-02 18:00:00             1.0 2021-12-29 04:55:00 2021-12-29 04:55:00
# 2022-01-02 18:30:00             0.0 2021-12-30 17:45:00 2022-01-02 13:19:00
# 2022-01-02 18:30:00             1.0 2021-12-23 00:55:00 2021-12-28 19:04:00
# 2022-01-02 18:30:00             2.0 2021-12-16 21:12:00 2021-12-19 22:53:00
# 2022-01-02 18:30:00             3.0 2021-12-14 18:45:00 2021-12-15 11:25:00
#
#                      Num_of_ticket  Purchase_Period  StartHour  \
# StartDate
# 2022-10-01 10:00:00              1                0         10
# 2022-10-01 18:00:00             40                0         18
# 2022-10-01 18:00:00             14                0         18
# 2022-10-01 18:00:00             28                0         18
# 2022-10-01 18:00:00              5                0         18
# ...                            ...              ...        ...
# 2022-01-02 18:00:00              1                0         18
# 2022-01-02 18:30:00              8                2         18
# 2022-01-02 18:30:00             27                5         18
# 2022-01-02 18:30:00              3                3         18
# 2022-01-02 18:30:00              2                0         18
#
#                      StartDayofweek  StartQuarter  StartDayofyear
# StartDate
# 2022-10-01 10:00:00               5             4             274
# 2022-10-01 18:00:00               5             4             274
# 2022-10-01 18:00:00               5             4             274
# 2022-10-01 18:00:00               5             4             274
# 2022-10-01 18:00:00               5             4             274
# ...                             ...           ...             ...
# 2022-01-02 18:00:00               6             1               2
# 2022-01-02 18:30:00               6             1               2
# 2022-01-02 18:30:00               6             1               2
# 2022-01-02 18:30:00               6             1               2
# 2022-01-02 18:30:00               6             1               2
#
# [8549 rows x 14 columns]

# %% [markdown]
# ### Visualize our Features to Target Relationship

# %%
# Split dataset 
split_size = int(0.7*len(data1))

train_data1 = data1.iloc[:split_size, :]
test_data1 = data1.iloc[split_size:, :]

# %%
# sns.set(rc={'figure.figsize':(12,10)})
# ax = sns.boxplot(data=data1, x='StartHour', y='Purchase_Period')
# ax.set_title('Event Start Dates Purchase Period')

# %% [markdown]
# ### Creating Model

# %%
train_data1 = create_features(train_data1)
test_data1 = create_features(test_data1)

# FEATURES = ['Season','Num_of_ticket', 'Min_Purchase_Day','Max_Purchase_Day']

FEATURES = ['Season', 'StartWeek', 'StartYear', 'StartMonth', 'EventType',
       'Weeks to Event','Num_of_ticket', 'Min_Purchase_Day','Max_Purchase_Day']
TARGET = 'Purchase_Period'

# FEATURES = ['Season','Weeks to Event','StartWeek',]
# TARGET = 'Num_of_ticket'

# %%
X_train_data1 = train_data1[FEATURES]
y_train_data1 = train_data1[TARGET]

X_test_data1 = test_data1[FEATURES]
y_test_data1 = test_data1[TARGET]

# %%
reg = xgb.XGBRegressor(n_estimators=500,early_stopping_rounds=50, learning_rate=0.01)
reg.fit(X_train_data1, y_train_data1, 
        eval_set=[(X_train_data1, y_train_data1), (X_test_data1, y_test_data1)],
        verbose=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\KingRemy\OneDrive - University of Keele\Documents\Collaborative App Development\Coursework\02_EDA\01_EDA copy 2.ipynb Cell 43 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/Collaborative%20App%20Development/Coursework/02_EDA/01_EDA%20copy%202.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> reg = xgb.XGBRegressor(n_estimators=500,early_stopping_rounds=50, learning_rate=0.01)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/Collaborative%20App%20Development/Coursework/02_EDA/01_EDA%20copy%202.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a> reg.fit(X_train_data1, y_train_data1,
#       <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/Collaborative%20App%20Development/Coursework/02_EDA/01_EDA%20copy%202.ipynb#X60sZmlsZQ%3D%3D?line=2'>3</a>         eval_set=[(X_train_data1, y_train_data1), (X_test_data1, y_test_data1)],
#       <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/Collaborative%20App%20Development/Coursework/02_EDA/01_EDA%20copy%202.ipynb#X60sZmlsZQ%3D%3D?line=3'>4</a>         verbose=50)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\sklearn.py:988, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     986 with config_context(verbosity=self.verbosity):
#     987     evals_result: TrainingCallback.EvalsLog = {}
# --> 988     train_dmatrix, evals = _wrap_evaluation_matrices(
#     989         missing=self.missing,
#     990         X=X,
#     991         y=y,
#     992         group=None,
#     993         qid=None,
#     994         sample_weight=sample_weight,
#     995         base_margin=base_margin,
#     996         feature_weights=feature_weights,
#     997         eval_set=eval_set,
#     998         sample_weight_eval_set=sample_weight_eval_set,
#     999         base_margin_eval_set=base_margin_eval_set,
#    1000         eval_group=None,
#    1001         eval_qid=None,
#    1002         create_dmatrix=self._create_dmatrix,
#    1003         enable_categorical=self.enable_categorical,
#    1004         feature_types=self.feature_types,
#    1005     )
#    1006     params = self.get_xgb_params()
#    1008     if callable(self.objective):
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\sklearn.py:908, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     906     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     907         pass
# --> 908 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\core.py:743, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     740     assert self.handle is not None
#     741     return
# --> 743 handle, feature_names, feature_types = dispatch_data_backend(
#     744     data,
#     745     missing=self.missing,
#     746     threads=self.nthread,
#     747     feature_names=feature_names,
#     748     feature_types=feature_types,
#     749     enable_categorical=enable_categorical,
#     750 )
#     751 assert handle is not None
#     752 self.handle = handle
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\data.py:970, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     968     return _from_tuple(data, missing, threads, feature_names, feature_types)
#     969 if _is_pandas_df(data):
# --> 970     return _from_pandas_df(data, enable_categorical, missing, threads,
#     971                            feature_names, feature_types)
#     972 if _is_pandas_series(data):
#     973     return _from_pandas_series(
#     974         data, missing, threads, enable_categorical, feature_names, feature_types
#     975     )
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\data.py:417, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     409 def _from_pandas_df(
#     410     data: DataFrame,
#     411     enable_categorical: bool,
#    (...)
#     415     feature_types: Optional[FeatureTypes],
#     416 ) -> DispatchedDataBackendReturnType:
# --> 417     data, feature_names, feature_types = _transform_pandas_df(
#     418         data, enable_categorical, feature_names, feature_types
#     419     )
#     420     return _from_numpy_array(data, missing, nthread, feature_names, feature_types)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\data.py:391, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     379 from pandas.api.types import (
#     380     is_sparse,
#     381     is_categorical_dtype,
#     382 )
#     384 if not all(
#     385     dtype.name in _pandas_dtype_mapper
#     386     or is_sparse(dtype)
#    (...)
#     389     for dtype in data.dtypes
#     390 ):
# --> 391     _invalid_dataframe_dtype(data)
#     393 feature_names, feature_types = _pandas_feature_info(
#     394     data, meta, feature_names, feature_types, enable_categorical
#     395 )
#     397 transformed = _pandas_cat_null(data)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\xgboost\data.py:283, in _invalid_dataframe_dtype(data)
#     281 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     282 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 283 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:Min_Purchase_Day: datetime64[ns], Max_Purchase_Day: datetime64[ns]

# %% [markdown]
# ### Features Importance

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
                index=reg.feature_names_in_,
                columns=['importance'])

# %%
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %% [markdown]
# ### Forcast on Test

# %%
test_data1['Prediction'] = reg.predict(X_test_data1)
data1 = data1.merge(test_data1[['Prediction']], how='left', left_index=True, right_index=True)
ax = data1[['Purchase_Period']].plot(figsize=(15,5))
data1['Prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Purchase Period Data and Predictions')
plt.show()
# Out:
# C:\Users\KingRemy\AppData\Local\Temp\ipykernel_9528\85181675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['Prediction'] = reg.predict(X_test_data1)
